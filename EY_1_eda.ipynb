# %%
import pandas as pd
import numpy as np
import pyarrow as pa
from pyarrow import csv

# %%
month = 1
stop_times_file = f"2025-{month:02}_stop_times_combined.csv"
trips_file = f"2025-{month:02}_trips_combined.csv"
stop_times = csv.read_csv(stop_times_file)
stop_times
# Out:
# pyarrow.Table
# trip_uid: string
# stop_id: string
# track: string
# arrival_time: int64
# departure_time: int64
# last_observed: int64
# marked_past: int64
# ----
# ...

# %%
df = stop_times.to_pandas()
df.headan_
# Out:
#           trip_uid stop_id track  arrival_time  departure_time  last_observed  \
# 0  1735707600_7..S    701S     2           NaN    1.735726e+09     1735725601
# 1  1735707600_7..S    702S     1  1.735726e+09    1.735726e+09     1735725755
# 2  1735707600_7..S    705S     1  1.735726e+09    1.735726e+09     1735725860
# 3  1735707600_7..S    706S     1  1.735726e+09    1.735726e+09     1735725980
# 4  1735707600_7..S    707S     1  1.735726e+09    1.735726e+09     1735726085
#
#     marked_past
# 0  1.735726e+09
# 1  1.735726e+09
# 2  1.735726e+09
# 3  1.735726e+09
# 4  1.735726e+09
